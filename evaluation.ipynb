# %%
import json
import pandas as pd

from PULS.evaluation import (
    evaluate_shifted_pi_estimation,
    evaluate_shifted_pi_estimation_from_all_data,
    evaluate_all_metrics,
    evaluate_all_metrics_from_all_data
)
from PULS.visualization import plot_mae, plot_metric, plot_roc_grid, plot_accuracy_threshold

# %%
# extreme class imbalance pi=0.9 pi'=0.99

dataset_name = 'GaussNew'
mean = 0.8
n = 5000
label_frequency = 0.5

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, [0.9], [0.99], convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['accuracy', 'balanced_accuracy'])]
df_metric["average_value"] = df_metric["average_value"].round(4)
df_metric["se"] = df_metric["se"].round(4)
df_metric["value"] = df_metric["average_value"].map(lambda x: f"{x:.4f}") + " +- " + df_metric["se"].map(lambda x: f"{x:.4f}")
df_metric[["method", "value", "metric", "converged"]]
# Out:
#           method             value             metric converged
# 0           nnPU  0.8802 +- 0.0068           accuracy        10
# 7           nnPU  0.8583 +- 0.0037  balanced_accuracy        10
# 8   nnPU+TA+True  0.9906 +- 0.0001           accuracy        10
# 15  nnPU+TA+True  0.5666 +- 0.0030  balanced_accuracy        10
# 16   nnPU+TA+KM2  0.0100 +- 0.0000           accuracy        10
# 23   nnPU+TA+KM2  0.5000 +- 0.0000  balanced_accuracy        10
# 24     nnPU+MLLS  0.0000 +- 0.0000           accuracy         0
# 31     nnPU+MLLS  0.0000 +- 0.0000  balanced_accuracy         0
# 32   nnPU+Target  0.0638 +- 0.0074           accuracy        10
# 39   nnPU+Target  0.4955 +- 0.0031  balanced_accuracy        10
# 40   nnPU+TA+DRE  0.7546 +- 0.0168           accuracy        10
# 47   nnPU+TA+DRE  0.8167 +- 0.0058  balanced_accuracy        10
# 48          DRPU  0.5747 +- 0.0183           accuracy        10
# 55          DRPU  0.6961 +- 0.0043  balanced_accuracy        10
# ...

# %% [markdown]
# ## Gauss

# %%
# Average Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'GaussNew'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['accuracy'])]
df_metric = df_metric[~df_metric['method'].isin(['DRPU+MLLS', 'nnPU+MLLS', 'nnPU+Target', 'DRPU+Target'])]

plot_metric(df_metric, 'Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='ta')
# Out:
# Saved plot to results_img\gauss_0.5_accuracy_ta.png
# Saved plot to results_img\gauss_0.5_accuracy_ta.png

# %%
# Average Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'GaussNew'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['accuracy'])]
df_metric = df_metric[df_metric['method'].isin(['DRPU', 'nnPU', 'nnPU+Target', 'DRPU+Target'])]

plot_metric(df_metric, 'Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='target')
# Out:
# Saved plot to results_img\gauss_0.5_accuracy_target.png
# Saved plot to results_img\gauss_0.5_accuracy_target.png

# %%
# Average Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'GaussNew'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['accuracy'])]
df_metric = df_metric[df_metric['method'].isin(['DRPU+MLLS', 'nnPU+MLLS', 'nnPU', 'DRPU'])]
plot_metric(df_metric, 'Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='mlls')
# Out:
# Saved plot to results_img\gauss_0.5_accuracy_mlls.png

# %%
# Average Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'GaussNew'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]
methods = ['nnPU', 'nnPU+TA+True', 'nnPU+TA+KM2']

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False, nnpu_only=True)
df_metric_ce = evaluate_all_metrics(dataset_name+'-CE', mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False, nnpu_only=True)
df_metric = df_metric[df_metric['method'].isin(methods)]
df_metric_ce = df_metric_ce[df_metric_ce['method'].isin(methods)]
df_metric["method"] = df_metric["method"] + " (Sig)"
df_metric_ce["method"] = df_metric_ce["method"] + " (CE)"
df_metric = pd.concat([df_metric, df_metric_ce], ignore_index=True)
df_metric = df_metric[df_metric['metric'].isin(['accuracy'])]

plot_metric(df_metric, 'Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='loss_ta')
# Out:
# Saved plot to results_img\gauss_0.5_accuracy_loss_ta.png
# Saved plot to results_img\gauss_0.5_accuracy_loss_ta.png

# %%
# Average Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'GaussNew'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]
methods = ['nnPU+MLLS', 'nnPU+Target']

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False, nnpu_only=True)
df_metric_ce = evaluate_all_metrics(dataset_name+'-CE', mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False, nnpu_only=True)
df_metric = df_metric[df_metric['method'].isin(methods)]
df_metric_ce = df_metric_ce[df_metric_ce['method'].isin(methods)]
df_metric["method"] = df_metric["method"] + " (Sig)"
df_metric_ce["method"] = df_metric_ce["method"] + " (CE)"
df_metric = pd.concat([df_metric, df_metric_ce], ignore_index=True)
df_metric = df_metric[df_metric['metric'].isin(['accuracy'])]

plot_metric(df_metric, 'Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='loss_target')
# Out:
# Saved plot to results_img\gauss_0.5_accuracy_loss_target.png

# %%
# Mean Absolute Error of test prior estimation for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'GaussNew'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]

df_mae = evaluate_shifted_pi_estimation(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False, nnpu_only=False)
df_mae["method"] = df_mae["method"].replace({"MLLS_NNPU": "MLLS (nnPU)", "MLLS_DRPU": "MLLS (DRPU)", "DRE_FROM_MIXED": "DRE (Target)"})
plot_mae(df_mae, pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier=None)
# Out:
# Saved plot to results_img\gauss_0.5_mae.png

# %%
# Average Balanced Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'GaussNew'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['balanced_accuracy'])]
df_metric = df_metric[~df_metric['method'].isin(['DRPU+MLLS', 'nnPU+MLLS', 'nnPU+Target', 'DRPU+Target'])]

plot_metric(df_metric, 'Balanced Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='ta')
# Out:
# Saved plot to results_img\gauss_0.5_balanced_accuracy_ta.png
# Saved plot to results_img\gauss_0.5_balanced_accuracy_ta.png

# %%
# Average Balanced Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'GaussNew'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['balanced_accuracy'])]
df_metric = df_metric[df_metric['method'].isin(['DRPU', 'nnPU', 'nnPU+Target', 'DRPU+Target'])]

plot_metric(df_metric, 'Balanced Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='target')
# Out:
# Saved plot to results_img\gauss_0.5_balanced_accuracy_target.png

# %%
# Average Balanced Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'GaussNew'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['balanced_accuracy'])]
df_metric = df_metric[df_metric['method'].isin(['DRPU+MLLS', 'nnPU+MLLS', 'nnPU', 'DRPU'])]
plot_metric(df_metric, 'Balanced Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='mlls')
# Out:
# Saved plot to results_img\gauss_0.5_balanced_accuracy_mlls.png

# %%
# ROC Curve

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.2, 0.4), (0.4, 0.2), (0.4, 0.8), (0.8, 0.4)]
metrics_list = []
for train_pi, test_pi in pi_pairs:
    file_path = f"output/GaussNew/{n}/0.8/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics_list.append(json.load(f))

plot_roc_grid(
    metrics_list,  
    model='nnpu',
    pi_pairs=pi_pairs,
    save=True,
    dataset_name='gauss'
)
# Out:
# Saved plot to results_img\gauss_0.2-0.4_0.4-0.2_0.4-0.8_0.8-0.4_roc_grid_nnpu.png
# (<Figure size 1000x1000 with 4 Axes>,
#  array([<Axes: title={'center': "$\\pi=0.2, \\pi'=0.4$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.4, \\pi'=0.2$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.4, \\pi'=0.8$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.8, \\pi'=0.4$"}, xlabel='FPR', ylabel='TPR'>],
#        dtype=object))

# %%
# ROC Curve

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.2, 0.4), (0.4, 0.2), (0.4, 0.8), (0.8, 0.4)]
metrics_list = []
for train_pi, test_pi in pi_pairs:
    file_path = f"output/GaussNew/{n}/0.8/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics_list.append(json.load(f))

plot_roc_grid(
    metrics_list, 
    model='drpu',
    pi_pairs=pi_pairs,
    save=True,
    dataset_name='gauss'
)
# Out:
# Saved plot to results_img\gauss_0.2-0.4_0.4-0.2_0.4-0.8_0.8-0.4_roc_grid_drpu.png
# (<Figure size 1000x1000 with 4 Axes>,
#  array([<Axes: title={'center': "$\\pi=0.2, \\pi'=0.4$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.4, \\pi'=0.2$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.4, \\pi'=0.8$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.8, \\pi'=0.4$"}, xlabel='FPR', ylabel='TPR'>],
#        dtype=object))

# %%
# Accuracy as function of threshold

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.2, 0.4), (0.4, 0.2), (0.4, 0.8), (0.8, 0.4)]
metrics_list = []
threshold_list = []

for train_pi, test_pi in pi_pairs:
    file_path = f"output/GaussNew/{n}/0.8/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics = json.load(f)
        metrics_list.append(metrics["accuracy-ta-grid"])

        threshold_list.append((
            metrics["nnPU+TA+KM2"]["threshold"],
            metrics["nnPU+TA+DRE"]["threshold"],
            metrics["nnPU+TA+True"]["threshold"]
        ))

plot_accuracy_threshold(
    metrics_list,
    pi_pairs=pi_pairs,
    thresholds_list=threshold_list,
    save=True,
)
# Out:
# Saved plot to results_img\accuracy_threshold_0.2-0.4_0.4-0.2_0.4-0.8_0.8-0.4_.png
# (<Figure size 1200x1600 with 8 Axes>,
#  array([[<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>]],
#        dtype=object))

# %% [markdown]
# ## MNIST

# %%
# Average Accuracy of different trained classifiers for MNIST Dataset (n = n′ = 5000, K = 10)

dataset_name = 'MNIST'
mean = None
n = 5000
label_frequency = 0.5
train_pis = [0.5]
test_pis = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, train_pis, test_pis, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['accuracy'])]
df_metric = df_metric[df_metric['method'].isin(['DRPU', 'nnPU', 'nnPU+TA+KM2', 'DRPU+TA+KM2', 'nnPU+Target'])]

plot_metric(df_metric, 'Accuracy', train_pis[0], test_pis, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='mnist', identifier='', is_real=True)
# Out:
# Saved plot to results_img\mnist_0.5_accuracy.png

# %%
# Mean Absolute Error of test prior estimation for MNIST Dataset (n = n′ = 5000, K = 10)

dataset_name = 'MNIST'
mean = None
n = 5000
label_frequency = 0.5
train_pis = [0.5]
test_pis = [0.2, 0.4, 0.6, 0.8]

df_mae = evaluate_shifted_pi_estimation(dataset_name, mean, n, label_frequency, train_pis, test_pis, convert_to_df=True, single_exp=False, nnpu_only=False)
df_mae = df_mae[df_mae['method'].isin(['KM2', 'DRE'])]
df_mae["method"] = df_mae["method"].replace({"MLLS_NNPU": "MLLS (nnPU)", "MLLS_DRPU": "MLLS (DRPU)", "DRE_FROM_MIXED": "DRE (Target)"})
plot_mae(df_mae, train_pis[0], test_pis, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='mnist', identifier=None, is_real=True)
# Out:
# Saved plot to results_img\mnist_0.5_mae.png

# %%
# Average Balanced Accuracy of different trained classifiers for MNIST Dataset (n = n′ = 5000, K = 10)

dataset_name = 'MNIST'
mean = None
n = 5000
label_frequency = 0.5
train_pis = [0.5]
test_pis = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, train_pis, test_pis, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['balanced_accuracy'])]
df_metric = df_metric[df_metric['method'].isin(['DRPU', 'nnPU', 'nnPU+TA+KM2', 'DRPU+TA+KM2', 'nnPU+Target'])]

plot_metric(df_metric, 'Balanced Accuracy', train_pis[0], test_pis, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='mnist', identifier='', is_real=True)
# Out:
# Saved plot to results_img\mnist_0.5_balanced_accuracy.png

# %%
# ROC Curve

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.5, 0.2), (0.5, 0.4), (0.5, 0.6), (0.5, 0.8)]
metrics_list = []
for train_pi, test_pi in pi_pairs:
    file_path = f"output/MNIST/{n}/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics_list.append(json.load(f))

plot_roc_grid(
    metrics_list,  
    model='nnpu',
    pi_pairs=pi_pairs,
    save=True,
    dataset_name='mnist'
)
# Out:
# Saved plot to results_img\mnist_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_roc_grid_nnpu.png
# (<Figure size 1000x1000 with 4 Axes>,
#  array([<Axes: title={'center': "$\\pi=0.5, \\pi'=0.2$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.4$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.6$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.8$"}, xlabel='FPR', ylabel='TPR'>],
#        dtype=object))

# %%
# ROC Curve

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.5, 0.2), (0.5, 0.4), (0.5, 0.6), (0.5, 0.8)]
metrics_list = []
for train_pi, test_pi in pi_pairs:
    file_path = f"output/MNIST/{n}/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics_list.append(json.load(f))

plot_roc_grid(
    metrics_list,  
    model='drpu',
    pi_pairs=pi_pairs,
    save=True,
    dataset_name='mnist'
)
# Out:
# Saved plot to results_img\mnist_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_roc_grid_drpu.png
# (<Figure size 1000x1000 with 4 Axes>,
#  array([<Axes: title={'center': "$\\pi=0.5, \\pi'=0.2$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.4$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.6$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.8$"}, xlabel='FPR', ylabel='TPR'>],
#        dtype=object))

# %%
# Accuracy as function of threshold

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.5, 0.2), (0.5, 0.4), (0.5, 0.6), (0.5, 0.8)]
metrics_list = []
threshold_list = []

for train_pi, test_pi in pi_pairs:
    file_path = f"output/MNIST/{n}/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics = json.load(f)
        metrics_list.append(metrics["accuracy-ta-grid"])

        threshold_list.append((
            metrics["nnPU+TA+KM2"]["threshold"],
            metrics["nnPU+TA+DRE"]["threshold"],
            metrics["nnPU+TA+True"]["threshold"]
        ))

plot_accuracy_threshold(
    metrics_list,
    pi_pairs=pi_pairs,
    thresholds_list=threshold_list,
    save=True,
    dataset_name='mnist',
)
# Out:
# Saved plot to results_img\accuracy_threshold_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_.png
# (<Figure size 1200x1600 with 8 Axes>,
#  array([[<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>]],
#        dtype=object))

# %% [markdown]
# ## FashionMNIST

# %%
dataset_name = 'FashionMNIST'
n = 50_000
label_frequency = 0.1
train_pi = [0.5]
test_pi = [0.2, 0.4, 0.6, 0.8]

df = evaluate_shifted_pi_estimation(dataset_name, None, n, label_frequency, train_pi, test_pi, convert_to_df=True, single_exp=True)
df['mae'] = abs(df['estimated_test_pi'] - df['new_pi'])
# df.pivot(index=["pi", "new_pi"], columns="method", values="mae")

df = df[~(df['method'].isin(['MLLS_DRPU']))]

sns.set_theme(style="whitegrid")
sns.lineplot(
    data=df,
    x="new_pi",
    y="mae",
    hue="method",
    marker="o",
    markersize=6,
    linestyle="-",
    linewidth=1,
)
plt.xticks(test_pi)
plt.xlabel("True test prior")
plt.ylabel("MAE")
plt.title(f"label frequency = {label_frequency}, train prior = 0.5")
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title="Method", loc='upper left')
plt.show()

# %%
dataset_name = 'MNIST'
n = 50_000
label_frequency = 0.1
train_pi = [0.5]
test_pi = [0.2, 0.4, 0.6, 0.8]

df = evaluate_all_TC_metrics(dataset_name, None, n, label_frequency, train_pi, test_pi, convert_to_df=True, single_exp=True)
df = df[df['metric'].isin(['accuracy'])]

# filter out model = 'nnpu' and method = 'mlls-drpu' or model = 'drpu' and method = 'mlls-nnpu'
df = df[~((df['model'] == 'nnpu') & (df['method'] == 'mlls-drpu')) & ~((df['model'] == 'drpu') & (df['method'] == 'mlls-nnpu'))]

model_mapping = {"drpu": "DRPU", "nnpu": "nnPU"}
method_mapping = {"DR": "DRE", "KM1": "KM1", "KM2": "KM2", "mlls-drpu": "MLLS", "mlls-nnpu": "MLLS", "train": "Train", "true": "True"}
df['model'] = df['model'].map(model_mapping)
df['method'] = df['method'].map(method_mapping)
df['model-method'] = df['model'] + ' + ' + df['method']
df.pivot(index=["pi", "new_pi"], columns="model-method", values="average_value")
# Out:
# model-method  DRPU + DRE  DRPU + KM1  DRPU + KM2  DRPU + MLLS  DRPU + Train
# pi  new_pi
# 0.5 0.2           0.9634      0.9730      0.9712       0.7068        0.8836  \
#     0.4           0.9522      0.9460      0.9388       0.7780        0.9080
#     0.6           0.9400      0.9208      0.9208       0.8502        0.9348
#     0.8           0.9526      0.9388      0.9506       0.9268        0.9648
#
# model-method  DRPU + True  nnPU + DRE  nnPU + KM1  nnPU + KM2  nnPU + MLLS
# pi  new_pi
# 0.5 0.2            0.9634      0.9628      0.9656      0.9658       0.9644  \
#     0.4            0.9522      0.9488      0.9482      0.9492       0.9486
#     0.6            0.9400      0.9466      0.9492      0.9492       0.9502
#     0.8            0.9526      0.9542      0.9590      0.9554       0.9578
#
# model-method  nnPU + Train  nnPU + True
# pi  new_pi
# 0.5 0.2             0.9574       0.9654
#     0.4             0.9508       0.9490
#     0.6             0.9468       0.9500
# ...

# %%
# filter out MLLS
df = df[~df['model-method'].str.contains('DRPU \+ MLLS')]

# MAE of test prior estimates for different training priors
df = df.sort_values(['pi', 'new_pi'])

fig = plt.figure(figsize=(8, 6))
sns.set_theme(style="whitegrid")
palette = sns.color_palette("tab20")

sns.lineplot(
    data=df,
    x="new_pi",
    y="average_value",
    hue="model-method",
    marker="o",
    markersize=6,
    linestyle="-",
    linewidth=1,
    ax=plt.gca(),
    palette=palette
)

plt.xticks([0.2, 0.4, 0.6, 0.8])
plt.gca().yaxis.grid(True, linestyle='--')
plt.gca().xaxis.grid(True, linestyle='--')

plt.xlabel("True test prior")
plt.ylabel("Average Accuracy")
plt.title("Label frequency = 0.1, Training prior = 0.5")
plt.tight_layout()
plt.legend(title="Model + Method", loc='lower right')
plt.show()
# Out:
# C:\Users\izate\AppData\Local\Temp\ipykernel_1184120\1851507768.py:11: UserWarning: The palette list has more values (20) than needed (11), which may not be intended.
#   sns.lineplot(

# %% [markdown]
# ### all data

# %%
label_frequencies=[0.1, 0.25]

df = evaluate_shifted_pi_estimation_from_all_data(
    dataset_name='FashionMNIST',
    mean=None,
    label_frequencies=label_frequencies,
    convert_to_df=True,
)

method_mapping = {"dre": "DRE", "km1": "KM1", "km2": "KM2", "mlls_drpu": "MLLS-DRPU", "mlls_nnpu": "MLLS-nnPU", "true": "true" }
df['method'] = df['method'].map(method_mapping)

true_pi = df[df['method'] == 'true'].iloc[0]['estimated_test_pi']
df['mae'] = abs(df['estimated_test_pi'] - true_pi)
df = df[df['method'] != 'true']
df['mae'] = df['mae'].round(3)
df.pivot(index=["label_frequency"], columns="method", values="mae")
# fig = plt.figure(figsize=(8, 6))
# sns.set_theme(style="whitegrid")
# palette = sns.color_palette("tab20")
# sns.lineplot(
#     data=df,
#     x="label_frequency",
#     y="mae",
#     hue="method",
#     marker="o",
#     markersize=6,
#     linestyle="-",
#     linewidth=1,
#     ax=plt.gca(),
#     palette=palette
# )

# plt.xticks(label_frequencies)
# plt.gca().yaxis.grid(True, linestyle='--')
# plt.gca().xaxis.grid(True, linestyle='--')

# plt.xlabel("Label Frequency")
# plt.ylabel("MAE")
# plt.title(f"True test prior = {true_pi.round(2)}")
# plt.tight_layout()
# plt.legend(title="Method", loc='upper right')
# plt.show()
# Out:
# method             DRE    KM1    KM2  MLLS-DRPU  MLLS-nnPU
# label_frequency
# 0.10             0.130  0.015  0.013      0.499      0.012
# 0.25             0.155  0.022  0.019      0.499      0.019

# %%
label_frequencies=[0.1, 0.25]

df = evaluate_all_TC_metrics_from_all_data(
    dataset_name='ChestXRay',
    mean=None,
    label_frequencies=label_frequencies,
    convert_to_df=True,
)

df = df[df['metric'].isin(['accuracy'])]

# filter out model = 'nnpu' and method = 'mlls-drpu' or model = 'drpu' and method = 'mlls-nnpu'
df = df[~((df['model'] == 'nnpu') & (df['method'] == 'mlls-drpu')) & ~((df['model'] == 'drpu') & (df['method'] == 'mlls-nnpu'))]

model_mapping = {"drpu": "DRPU", "nnpu": "nnPU"}
method_mapping = {"DR": "DRE", "KM1": "KM1", "KM2": "KM2", "mlls-drpu": "MLLS", "mlls-nnpu": "MLLS", "train": "Train", "true": "True"}
df['model'] = df['model'].map(model_mapping)
df['method'] = df['method'].map(method_mapping)
df['model-method'] = df['model'] + ' + ' + df['method']
df['average_value'] = df['average_value'].round(3)
df.pivot(index=["label_frequency"], columns="model-method", values="average_value")
# Out:
# model-method     DRPU + DRE  DRPU + KM1  DRPU + KM2  DRPU + MLLS
# label_frequency
# 0.10                  0.639       0.686       0.605        0.399  \
# 0.25                  0.668       0.734       0.741        0.402
#
# model-method     DRPU + Train  DRPU + True  nnPU + DRE  nnPU + KM1
# label_frequency
# 0.10                    0.761        0.639       0.595       0.773  \
# 0.25                    0.821        0.668       0.586       0.826
#
# model-method     nnPU + KM2  nnPU + MLLS  nnPU + Train  nnPU + True
# label_frequency
# 0.10                  0.469        0.294         0.895        0.895
# 0.25                  0.840        0.294         0.928        0.921

# %% [markdown]
# ## Chest X Ray

# %%
dataset_name = 'ChestXRay'
n = 2_475
label_frequency = 0.2
train_pi = [0.5]
test_pi = [0.2, 0.4, 0.6, 0.8]

df = evaluate_shifted_pi_estimation(dataset_name, None, n, label_frequency, train_pi, test_pi, convert_to_df=True, single_exp=True)
df['mae'] = abs(df['estimated_test_pi'] - df['new_pi'])
# df.pivot(index=["pi", "new_pi"], columns="method", values="mae")

df = df[~(df['method'].isin(['MLLS_DRPU']))]

sns.set_theme(style="whitegrid")
sns.lineplot(
    data=df,
    x="new_pi",
    y="mae",
    hue="method",
    marker="o",
    markersize=6,
    linestyle="-",
    linewidth=1,
)
plt.xticks(test_pi)
plt.xlabel("True test prior")
plt.ylabel("MAE")
plt.title(f"label frequency = {label_frequency}, train prior = 0.5")
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title="Method", loc='upper left')
plt.show()

# %%
dataset_name = 'ChestXRay'
n = 2_475
label_frequency = 0.2
train_pi = [0.5]
test_pi = [0.2, 0.4, 0.6, 0.8]

df = evaluate_all_TC_metrics(dataset_name, None, n, label_frequency, train_pi, test_pi, convert_to_df=True, single_exp=True)
df = df[df['metric'].isin(['accuracy'])]

# filter out model = 'nnpu' and method = 'mlls-drpu' or model = 'drpu' and method = 'mlls-nnpu'
df = df[~((df['model'] == 'nnpu') & (df['method'] == 'mlls-drpu')) & ~((df['model'] == 'drpu') & (df['method'] == 'mlls-nnpu'))]

model_mapping = {"drpu": "DRPU", "nnpu": "nnPU"}
method_mapping = {"DR": "DRE", "KM1": "KM1", "KM2": "KM2", "mlls-drpu": "MLLS", "mlls-nnpu": "MLLS", "train": "Train", "true": "True"}
df['model'] = df['model'].map(model_mapping)
df['method'] = df['method'].map(method_mapping)
df['model-method'] = df['model'] + ' + ' + df['method']
df.pivot(index=["pi", "new_pi"], columns="model-method", values="average_value")
# Out:
# model-method  DRPU + DRE  DRPU + KM1  DRPU + KM2  DRPU + MLLS  DRPU + Train
# pi  new_pi
# 0.5 0.2            0.845       0.805       0.885        0.850         0.940  \
#     0.4            0.690       0.615       0.770        0.870         0.865
#     0.6            0.665       0.435       0.670        0.890         0.790
#     0.8            0.650       0.245       0.360        0.925         0.745
#
# model-method  DRPU + True  nnPU + DRE  nnPU + KM1  nnPU + KM2  nnPU + MLLS
# pi  new_pi
# 0.5 0.2             0.845       0.800         0.8       0.830         0.80  \
#     0.4             0.690       0.610         0.6       0.765         0.84
#     0.6             0.665       0.665         0.4       0.735         0.75
#     0.8             0.650       0.830         0.2       0.215         0.80
#
# model-method  nnPU + Train  nnPU + True
# pi  new_pi
# 0.5 0.2              0.880        0.825
#     0.4              0.885        0.885
#     0.6              0.890        0.860
# ...

# %%
# filter out MLLS
df = df[~df['model-method'].str.contains('DRPU \+ MLLS')]

# MAE of test prior estimates for different training priors
df = df.sort_values(['pi', 'new_pi'])

fig = plt.figure(figsize=(8, 6))
sns.set_theme(style="whitegrid")
palette = sns.color_palette("tab20")

sns.lineplot(
    data=df,
    x="new_pi",
    y="average_value",
    hue="model-method",
    marker="o",
    markersize=6,
    linestyle="-",
    linewidth=1,
    ax=plt.gca(),
    palette=palette
)

plt.xticks([0.2, 0.4, 0.6, 0.8])
plt.gca().yaxis.grid(True, linestyle='--')
plt.gca().xaxis.grid(True, linestyle='--')

plt.xlabel("True test prior")
plt.ylabel("Average Accuracy")
plt.title("Training prior = 0.5, Label frequency = 0.2")
plt.tight_layout()
plt.legend(title="Model + Method", loc='lower left')
plt.show()
# Out:
# C:\Users\izate\AppData\Local\Temp\ipykernel_1184120\379621415.py:11: UserWarning: The palette list has more values (20) than needed (11), which may not be intended.
#   sns.lineplot(

# %% [markdown]
# ### all data

# %%
df = evaluate_shifted_pi_estimation_from_all_data(
    dataset_name='ChestXRay',
    mean=None,
    label_frequencies=[0.1, 0.25, 0.5, 0.75, 0.9],
    convert_to_df=True,
)

method_mapping = {"dre": "DRE", "km1": "KM1", "km2": "KM2", "mlls_drpu": "MLLS-DRPU", "mlls_nnpu": "MLLS-nnPU", "true": "true" }
df['method'] = df['method'].map(method_mapping)

true_pi = df[df['method'] == 'true'].iloc[0]['estimated_test_pi']
df['mae'] = abs(df['estimated_test_pi'] - true_pi)
df = df[df['method'] != 'true']

fig = plt.figure(figsize=(8, 6))
sns.set_theme(style="whitegrid")
palette = sns.color_palette("tab20")
sns.lineplot(
    data=df,
    x="label_frequency",
    y="mae",
    hue="method",
    marker="o",
    markersize=6,
    linestyle="-",
    linewidth=1,
    ax=plt.gca(),
    palette=palette
)

plt.xticks([0.1, 0.25, 0.5, 0.75, 0.9])
plt.gca().yaxis.grid(True, linestyle='--')
plt.gca().xaxis.grid(True, linestyle='--')

plt.xlabel("Label Frequency")
plt.ylabel("MAE")
plt.title(f"True test prior = {true_pi.round(2)}")
plt.tight_layout()
plt.legend(title="Method", loc='upper right')
plt.show()
# Out:
# C:\Users\izate\AppData\Local\Temp\ipykernel_1014792\372237869.py:18: UserWarning: The palette list has more values (20) than needed (5), which may not be intended.
#   sns.lineplot(

# %%
label_frequencies=[0.1, 0.25, 0.5, 0.75, 0.9]

df = evaluate_all_TC_metrics_from_all_data(
    dataset_name='ChestXRay',
    mean=None,
    label_frequencies=label_frequencies,
    convert_to_df=True,
)

df = df[df['metric'].isin(['accuracy'])]

# filter out model = 'nnpu' and method = 'mlls-drpu' or model = 'drpu' and method = 'mlls-nnpu'
df = df[~((df['model'] == 'nnpu') & (df['method'] == 'mlls-drpu')) & ~((df['model'] == 'drpu') & (df['method'] == 'mlls-nnpu'))]

model_mapping = {"drpu": "DRPU", "nnpu": "nnPU"}
method_mapping = {"DR": "DRE", "KM1": "KM1", "KM2": "KM2", "mlls-drpu": "MLLS", "mlls-nnpu": "MLLS", "train": "Train", "true": "True"}
df['model'] = df['model'].map(model_mapping)
df['method'] = df['method'].map(method_mapping)
df['model-method'] = df['model'] + ' + ' + df['method']
df.pivot(index=["label_frequency"], columns="model-method", values="average_value")
# Out:
# model-method     DRPU + DRE  DRPU + KM1  DRPU + KM2  DRPU + MLLS
# label_frequency
# 0.10               0.639175    0.685567    0.604811     0.398625  \
# 0.25               0.668385    0.733677    0.740550     0.402062
# 0.50               0.766323    0.847079    0.853952     0.922680
# 0.75               0.902062    0.903780    0.907216     0.926117
# 0.90               0.898625    0.900344    0.903780     0.931271
#
# model-method     DRPU + Train  DRPU + True  nnPU + DRE  nnPU + KM1
# label_frequency
# 0.10                 0.761168     0.639175    0.594502    0.773196  \
# 0.25                 0.821306     0.668385    0.585911    0.826460
# 0.50                 0.890034     0.766323    0.850515    0.932990
# 0.75                 0.879725     0.902062    0.932990    0.932990
# 0.90                 0.546392     0.898625    0.936426    0.936426
#
# model-method     nnPU + KM2  nnPU + MLLS  nnPU + Train  nnPU + True
# label_frequency
# ...

# %%
fig = plt.figure(figsize=(8, 6))
sns.set_theme(style="whitegrid")
palette = sns.color_palette("tab20")
sns.lineplot(
    data=df,
    x="label_frequency",
    y="average_value",
    hue="model-method",
    marker="o",
    markersize=6,
    linestyle="-",
    linewidth=1,
    ax=plt.gca(),
    palette=palette
)

plt.xticks([0.1, 0.25, 0.5, 0.75, 0.9])
plt.gca().yaxis.grid(True, linestyle='--')
plt.gca().xaxis.grid(True, linestyle='--')

plt.xlabel("Label Frequency")
plt.ylabel("Average Accuracy")
# plt.title(f"True test prior = {true_pi.round(2)}")
plt.tight_layout()
plt.legend(title="Model + Method", loc='lower right')
plt.show()
# Out:
# C:\Users\izate\AppData\Local\Temp\ipykernel_1184120\3644213849.py:4: UserWarning: The palette list has more values (20) than needed (12), which may not be intended.
#   sns.lineplot(

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# for method in df["method"].unique():
#     df_method = df[df["method"] == method]
#     plt.figure(figsize=(6, 4))
#     plt.title(f"Estimated pi ({method})")
#     sns.heatmap(df_method.pivot(index="pi", columns="new_pi", values="mean"), annot=True, fmt=".2f", 
#         cmap= "PiYG",
#         vmin= min(df_method["mean"]),
#         vmax= max(df_method["mean"]),
#         center=0)
#     plt.show()

# %%
import torch
print(f"Using device: {'cuda' if torch.cuda.is_available() else 'cpu'}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Using device: cuda
# GPU: NVIDIA GeForce RTX 5070 Ti
