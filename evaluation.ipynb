# %%
import json
import pandas as pd

from PULS.evaluation import (
    evaluate_shifted_pi_estimation,
    evaluate_shifted_pi_estimation_from_all_data,
    evaluate_shifted_pi_estimation_by_exp,
    evaluate_all_metrics,
    evaluate_all_metrics_from_all_data,
    evaluate_all_metrics_by_exp,
 )
from PULS.visualization import (
    plot_mae,
    plot_metric,
    plot_roc_grid,
    plot_accuracy_threshold,
    plot_real_accuracy_grid,
    plot_real_mae_grid,
    plot_boxplots_mae,
    plot_boxplots_metric
 )

# %% [markdown]
# ## Gauss

# %%
# extreme class imbalance pi=0.9 pi'=0.99

dataset_name = 'Gauss'
mean = 0.8
n = 5000
label_frequency = 0.5

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, [0.9], [0.99], convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['accuracy', 'balanced_accuracy'])]
df_metric["average_value"] = df_metric["average_value"].round(4)
df_metric["se"] = df_metric["se"].round(4)
df_metric["value"] = df_metric["average_value"].map(lambda x: f"{x:.4f}") + " +- " + df_metric["se"].map(lambda x: f"{x:.4f}")
df_metric[["method", "value", "metric", "converged"]]
# Out:
#           method             value             metric converged
# 0           nnPU  0.8802 +- 0.0069           accuracy        10
# 7           nnPU  0.8583 +- 0.0037  balanced_accuracy        10
# 8       nnPU+KM2  0.8628 +- 0.0048           accuracy        10
# 15      nnPU+KM2  0.8683 +- 0.0023  balanced_accuracy        10
# 16  nnPU+TA+True  0.9906 +- 0.0001           accuracy        10
# 23  nnPU+TA+True  0.5666 +- 0.0030  balanced_accuracy        10
# 24   nnPU+TA+KM2  0.0100 +- 0.0000           accuracy        10
# 31   nnPU+TA+KM2  0.5000 +- 0.0000  balanced_accuracy        10
# 32     nnPU+MLLS  0.0000 +- 0.0000           accuracy         0
# 39     nnPU+MLLS  0.0000 +- 0.0000  balanced_accuracy         0
# 40   nnPU+Target  0.0611 +- 0.0061           accuracy        10
# 47   nnPU+Target  0.4555 +- 0.0106  balanced_accuracy        10
# 48   nnPU+TA+DRE  0.8349 +- 0.0161           accuracy        10
# 55   nnPU+TA+DRE  0.8255 +- 0.0049  balanced_accuracy        10
# 56          DRPU  0.5846 +- 0.0194           accuracy        10
# 63          DRPU  0.6496 +- 0.0116  balanced_accuracy        10
# 64  DRPU+TA+True  0.7827 +- 0.0152           accuracy        10
# 71  DRPU+TA+True  0.6447 +- 0.0147  balanced_accuracy        10
# 72   DRPU+TA+KM2  0.0868 +- 0.0029           accuracy        10
# 79   DRPU+TA+KM2  0.5200 +- 0.0026  balanced_accuracy        10
# 80     DRPU+MLLS  0.0000 +- 0.0000           accuracy         0
# 87     DRPU+MLLS  0.0000 +- 0.0000  balanced_accuracy         0
# 88   DRPU+Target  0.0100 +- 0.0000           accuracy        10
# 95   DRPU+Target  0.5000 +- 0.0000  balanced_accuracy        10

# %%
# extreme class imbalance pi=0.9 pi'=0.99

dataset_name = 'Gauss'
mean = 0.8
n = 5000
label_frequency = 0.5

df_mae = evaluate_shifted_pi_estimation(dataset_name, mean, n, label_frequency, [0.9], [0.99], convert_to_df=True, single_exp=False)
df_mae["mae"] = df_mae["mae"].round(4)
df_mae["se"] = df_mae["se"].round(4)
df_mae["value"] = df_mae["mae"].map(lambda x: f"{x:.4f}") + " +- " + df_mae["se"].map(lambda x: f"{x:.4f}")
df_mae[["method", "value", "converged"]]
# Out:
#            method             value converged
# 0             KM2  0.9298 +- 0.0099        10
# 1             DRE  0.0966 +- 0.0031        10
# 2       MLLS_NNPU  0.0000 +- 0.0000         0
# 3       MLLS_DRPU  0.0000 +- 0.0000         0
# 4  DRE_FROM_MIXED  0.9265 +- 0.0015        10

# %%
# Boxplots for the extreme class imbalance experiment across 10 runs
# MLLS methods are excluded from both plots.

dataset_name = 'Gauss'
mean = 0.8
n = 5000
label_frequency = 0.5
train_pi = [0.9]
test_pi = [0.99]

df_metric = evaluate_all_metrics_by_exp(
    dataset_name,
    mean,
    n,
    label_frequency,
    train_pi,
    test_pi,
    single_exp=False,
 )
df_metric = df_metric[df_metric['metric'] == 'accuracy']
df_metric = df_metric[~df_metric['method'].str.contains('MLLS', case=False, na=False)]

df_mae = evaluate_shifted_pi_estimation_by_exp(
    dataset_name,
    mean,
    n,
    label_frequency,
    train_pi,
    test_pi,
    single_exp=False,
 )
df_mae = df_mae[~df_mae['method'].str.contains('MLLS', case=False, na=False)]

plot_boxplots_metric(df_metric, 'gauss', save=True, identifier='extreme')
plot_boxplots_mae(df_mae, 'gauss', save=True, identifier='extreme')
# Out:
# Saved plot to results_img\gauss_0.5_boxplot_accuracy_extreme.png
# Saved plot to results_img\gauss_0.5_boxplot_mae_extreme.png

# %%
# Average Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'Gauss'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['accuracy'])]
df_metric = df_metric[~df_metric['method'].isin(['DRPU+MLLS', 'nnPU+MLLS', 'nnPU+Target', 'DRPU+Target'])]

plot_metric(df_metric, 'Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='ta')
# Out:
# Saved plot to results_img\gauss_0.5_accuracy_ta.png

# %%
# Average Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'Gauss'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['accuracy'])]
df_metric = df_metric[df_metric['method'].isin(['DRPU', 'nnPU', 'nnPU+Target', 'DRPU+Target'])]

plot_metric(df_metric, 'Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='target')
# Out:
# Saved plot to results_img\gauss_0.5_accuracy_target.png

# %%
# Average Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'Gauss'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['accuracy'])]
df_metric = df_metric[df_metric['method'].isin(['DRPU+MLLS', 'nnPU+MLLS', 'nnPU', 'DRPU'])]
plot_metric(df_metric, 'Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='mlls')
# Out:
# Saved plot to results_img\gauss_0.5_accuracy_mlls.png

# %%
# Average Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'Gauss'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]
methods = ['nnPU', 'nnPU+KM2', 'nnPU+TA+True', 'nnPU+TA+KM2']

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False, nnpu_only=True)
df_metric_ce = evaluate_all_metrics(dataset_name+'-CE', mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False, nnpu_only=True)
df_metric = df_metric[df_metric['method'].isin(methods)]
df_metric_ce = df_metric_ce[df_metric_ce['method'].isin(methods)]
df_metric["method"] = df_metric["method"] + " (Sig)"
df_metric_ce["method"] = df_metric_ce["method"] + " (CE)"
df_metric = pd.concat([df_metric, df_metric_ce], ignore_index=True)
df_metric = df_metric[df_metric['metric'].isin(['accuracy'])]

plot_metric(df_metric, 'Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='loss_ta')
# Out:
# Saved plot to results_img\gauss_0.5_accuracy_loss_ta.png

# %%
# Average Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'Gauss'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]
methods = ['nnPU+MLLS', 'nnPU+Target']

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False, nnpu_only=True)
df_metric_ce = evaluate_all_metrics(dataset_name+'-CE', mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False, nnpu_only=True)
df_metric = df_metric[df_metric['method'].isin(methods)]
df_metric_ce = df_metric_ce[df_metric_ce['method'].isin(methods)]
df_metric["method"] = df_metric["method"] + " (Sig)"
df_metric_ce["method"] = df_metric_ce["method"] + " (CE)"
df_metric = pd.concat([df_metric, df_metric_ce], ignore_index=True)
df_metric = df_metric[df_metric['metric'].isin(['accuracy'])]

plot_metric(df_metric, 'Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='loss_target')
# Out:
# Saved plot to results_img\gauss_0.5_accuracy_loss_target.png

# %%
# Mean Absolute Error of test prior estimation for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'Gauss'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]

df_mae = evaluate_shifted_pi_estimation(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False, nnpu_only=False)
df_mae["method"] = df_mae["method"].replace({"MLLS_NNPU": "MLLS (nnPU)", "MLLS_DRPU": "MLLS (DRPU)", "DRE_FROM_MIXED": "DRE (Target)"})
plot_mae(df_mae, pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier=None)
# Out:
# Saved plot to results_img\gauss_0.5_mae.png

# %%
# Average Balanced Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'Gauss'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['balanced_accuracy'])]
df_metric = df_metric[~df_metric['method'].isin(['DRPU+MLLS', 'nnPU+MLLS', 'nnPU+Target', 'DRPU+Target'])]

plot_metric(df_metric, 'Balanced Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='ta')
# Out:
# Saved plot to results_img\gauss_0.5_balanced_accuracy_ta.png

# %%
# Average Balanced Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'Gauss'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['balanced_accuracy'])]
df_metric = df_metric[df_metric['method'].isin(['DRPU', 'nnPU', 'nnPU+Target', 'DRPU+Target'])]

plot_metric(df_metric, 'Balanced Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='target')
# Out:
# Saved plot to results_img\gauss_0.5_balanced_accuracy_target.png

# %%
# Average Balanced Accuracy of different trained classifiers for Gaussian Dataset (n = n′ = 5000, K = 10)

dataset_name = 'Gauss'
mean = 0.8
n = 5000
label_frequency = 0.5
pi_grid = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, pi_grid, pi_grid, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['balanced_accuracy'])]
df_metric = df_metric[df_metric['method'].isin(['DRPU+MLLS', 'nnPU+MLLS', 'nnPU', 'DRPU'])]
plot_metric(df_metric, 'Balanced Accuracy', pi_grid, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='gauss', identifier='mlls')
# Out:
# Saved plot to results_img\gauss_0.5_balanced_accuracy_mlls.png

# %%
# ROC Curve

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.2, 0.4), (0.4, 0.2), (0.4, 0.8), (0.8, 0.4)]
metrics_list = []
for train_pi, test_pi in pi_pairs:
    file_path = f"output/Gauss/{n}/0.8/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics_list.append(json.load(f))

plot_roc_grid(
    metrics_list,  
    model='nnpu',
    pi_pairs=pi_pairs,
    save=True,
    dataset_name='gauss'
)
# Out:
# Saved plot to results_img\gauss_0.2-0.4_0.4-0.2_0.4-0.8_0.8-0.4_roc_grid_nnpu.png
# (<Figure size 1000x1000 with 4 Axes>,
#  array([<Axes: title={'center': "$\\pi=0.2, \\pi'=0.4$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.4, \\pi'=0.2$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.4, \\pi'=0.8$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.8, \\pi'=0.4$"}, xlabel='FPR', ylabel='TPR'>],
#        dtype=object))

# %%
# ROC Curve

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.2, 0.4), (0.4, 0.2), (0.4, 0.8), (0.8, 0.4)]
metrics_list = []
for train_pi, test_pi in pi_pairs:
    file_path = f"output/Gauss/{n}/0.8/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics_list.append(json.load(f))

plot_roc_grid(
    metrics_list, 
    model='drpu',
    pi_pairs=pi_pairs,
    save=True,
    dataset_name='gauss'
)
# Out:
# Saved plot to results_img\gauss_0.2-0.4_0.4-0.2_0.4-0.8_0.8-0.4_roc_grid_drpu.png
# (<Figure size 1000x1000 with 4 Axes>,
#  array([<Axes: title={'center': "$\\pi=0.2, \\pi'=0.4$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.4, \\pi'=0.2$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.4, \\pi'=0.8$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.8, \\pi'=0.4$"}, xlabel='FPR', ylabel='TPR'>],
#        dtype=object))

# %%
# Accuracy as function of threshold

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.2, 0.4), (0.4, 0.2), (0.4, 0.8), (0.8, 0.4)]
metrics_list = []
threshold_list = []

for train_pi, test_pi in pi_pairs:
    file_path = f"output/Gauss/{n}/0.8/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics = json.load(f)
        metrics_list.append(metrics["accuracy-ta-grid"])

        threshold_list.append((
            metrics["nnPU+TA+KM2"]["threshold"],
            metrics["nnPU+TA+DRE"]["threshold"],
            metrics["nnPU+TA+True"]["threshold"]
        ))

plot_accuracy_threshold(
    metrics_list,
    pi_pairs=pi_pairs,
    thresholds_list=threshold_list,
    save=True,
    dataset_name='gauss',
)
# Out:
# Saved plot to results_img\gauss_accuracy_threshold_0.2-0.4_0.4-0.2_0.4-0.8_0.8-0.4_.png
# (<Figure size 1200x1600 with 8 Axes>,
#  array([[<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>]],
#        dtype=object))

# %%
# Accuracy as function of threshold (averaged over K experiments)

from numbers import Number

n = 5000
label_frequency = 0.5
K = 10
pi_pairs = [(0.2, 0.4), (0.4, 0.2), (0.4, 0.8), (0.8, 0.4)]
metrics_list = []
threshold_list = []

def average_nested(values):
    """Recursively average numeric values across a list of same-shaped structures."""
    first = values[0]

    if isinstance(first, dict):
        return {k: average_nested([v[k] for v in values]) for k in first}
    if isinstance(first, (list, tuple)):
        averaged = [average_nested([v[i] for v in values]) for i in range(len(first))]
        return tuple(averaged) if isinstance(first, tuple) else averaged
    if isinstance(first, Number):
        return sum(values) / len(values)

    return first

for train_pi, test_pi in pi_pairs:
    per_exp_metrics = []
    per_exp_thresholds = []

    for exp_number in range(K):
        file_path = f"output/Gauss/{n}/0.8/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
        with open(file_path, "r") as f:
            metrics = json.load(f)
            per_exp_metrics.append(metrics["accuracy-ta-grid"])
            per_exp_thresholds.append((
                metrics["nnPU+TA+KM2"]["threshold"],
                metrics["nnPU+TA+DRE"]["threshold"],
                metrics["nnPU+TA+True"]["threshold"]
            ))

    metrics_list.append(average_nested(per_exp_metrics))
    threshold_list.append(tuple(
        sum(th[i] for th in per_exp_thresholds) / len(per_exp_thresholds)
        for i in range(3)
    ))

plot_accuracy_threshold(
    metrics_list,
    pi_pairs=pi_pairs,
    thresholds_list=threshold_list,
    save=True,
    dataset_name='gauss',
)

# %% [markdown]
# ## MNIST

# %%
# Average Accuracy of different trained classifiers for MNIST Dataset (n = n′ = 5000, K = 10)

dataset_name = 'MNIST'
mean = None
n = 5000
label_frequency = 0.5
train_pis = [0.5]
test_pis = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, train_pis, test_pis, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['accuracy'])]
df_metric = df_metric[df_metric['method'].isin(['DRPU', 'nnPU', 'nnPU+TA+KM2', 'DRPU+TA+KM2', 'nnPU+Target'])]

plot_metric(df_metric, 'Accuracy', train_pis[0], test_pis, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='mnist', identifier='', is_real=True)
# Out:
# Saved plot to results_img\mnist_0.5_accuracy.png

# %%
# Mean Absolute Error of test prior estimation for MNIST Dataset (n = n′ = 5000, K = 10)

dataset_name = 'MNIST'
mean = None
n = 5000
label_frequency = 0.5
train_pis = [0.5]
test_pis = [0.2, 0.4, 0.6, 0.8]

df_mae = evaluate_shifted_pi_estimation(dataset_name, mean, n, label_frequency, train_pis, test_pis, convert_to_df=True, single_exp=False, nnpu_only=False)
df_mae = df_mae[df_mae['method'].isin(['KM2', 'DRE'])]
df_mae["method"] = df_mae["method"].replace({"MLLS_NNPU": "MLLS (nnPU)", "MLLS_DRPU": "MLLS (DRPU)", "DRE_FROM_MIXED": "DRE (Target)"})
plot_mae(df_mae, train_pis[0], test_pis, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='mnist', identifier=None, is_real=True)
# Out:
# Saved plot to results_img\mnist_0.5_mae.png

# %%
# Average Balanced Accuracy of different trained classifiers for MNIST Dataset (n = n′ = 5000, K = 10)

dataset_name = 'MNIST'
mean = None
n = 5000
label_frequency = 0.5
train_pis = [0.5]
test_pis = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, train_pis, test_pis, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['balanced_accuracy'])]
df_metric = df_metric[df_metric['method'].isin(['DRPU', 'nnPU', 'nnPU+TA+KM2', 'DRPU+TA+KM2', 'nnPU+Target'])]

plot_metric(df_metric, 'Balanced Accuracy', train_pis[0], test_pis, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='mnist', identifier='', is_real=True)
# Out:
# Saved plot to results_img\mnist_0.5_balanced_accuracy.png

# %%
# ROC Curve

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.5, 0.2), (0.5, 0.4), (0.5, 0.6), (0.5, 0.8)]
metrics_list = []
for train_pi, test_pi in pi_pairs:
    file_path = f"output/MNIST/{n}/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics_list.append(json.load(f))

plot_roc_grid(
    metrics_list,  
    model='nnpu',
    pi_pairs=pi_pairs,
    save=True,
    dataset_name='mnist'
)
# Out:
# Saved plot to results_img\mnist_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_roc_grid_nnpu.png
# (<Figure size 1000x1000 with 4 Axes>,
#  array([<Axes: title={'center': "$\\pi=0.5, \\pi'=0.2$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.4$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.6$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.8$"}, xlabel='FPR', ylabel='TPR'>],
#        dtype=object))

# %%
# ROC Curve

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.5, 0.2), (0.5, 0.4), (0.5, 0.6), (0.5, 0.8)]
metrics_list = []
for train_pi, test_pi in pi_pairs:
    file_path = f"output/MNIST/{n}/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics_list.append(json.load(f))

plot_roc_grid(
    metrics_list,  
    model='drpu',
    pi_pairs=pi_pairs,
    save=True,
    dataset_name='mnist'
)
# Out:
# Saved plot to results_img\mnist_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_roc_grid_drpu.png
# (<Figure size 1000x1000 with 4 Axes>,
#  array([<Axes: title={'center': "$\\pi=0.5, \\pi'=0.2$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.4$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.6$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.8$"}, xlabel='FPR', ylabel='TPR'>],
#        dtype=object))

# %%
# Accuracy as function of threshold

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.5, 0.2), (0.5, 0.4), (0.5, 0.6), (0.5, 0.8)]
metrics_list = []
threshold_list = []

for train_pi, test_pi in pi_pairs:
    file_path = f"output/MNIST/{n}/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics = json.load(f)
        metrics_list.append(metrics["accuracy-ta-grid"])

        threshold_list.append((
            metrics["nnPU+TA+KM2"]["threshold"],
            metrics["nnPU+TA+DRE"]["threshold"],
            metrics["nnPU+TA+True"]["threshold"]
        ))

plot_accuracy_threshold(
    metrics_list,
    pi_pairs=pi_pairs,
    thresholds_list=threshold_list,
    save=True,
    dataset_name='mnist',
)
# Out:
# Saved plot to results_img\mnist_accuracy_threshold_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_.png
# (<Figure size 1200x1600 with 8 Axes>,
#  array([[<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>]],
#        dtype=object))

# %% [markdown]
# ## FashionMNIST

# %%
# Average Accuracy of different trained classifiers for FashionMNIST Dataset (n = n′ = 5000, K = 10)

dataset_name = 'FashionMNIST'
mean = None
n = 5000
label_frequency = 0.5
train_pis = [0.5]
test_pis = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, train_pis, test_pis, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['accuracy'])]
df_metric = df_metric[df_metric['method'].isin(['DRPU', 'nnPU', 'nnPU+TA+KM2', 'DRPU+TA+KM2', 'nnPU+Target'])]

plot_metric(df_metric, 'Accuracy', train_pis[0], test_pis, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='fashionmnist', identifier='', is_real=True)
# Out:
# Saved plot to results_img\fashionmnist_0.5_accuracy.png

# %%
# Mean Absolute Error of test prior estimation for FashionMNIST Dataset (n = n′ = 5000, K = 10)

dataset_name = 'FashionMNIST'
mean = None
n = 5000
label_frequency = 0.5
train_pis = [0.5]
test_pis = [0.2, 0.4, 0.6, 0.8]

df_mae = evaluate_shifted_pi_estimation(dataset_name, mean, n, label_frequency, train_pis, test_pis, convert_to_df=True, single_exp=False, nnpu_only=False)
df_mae = df_mae[df_mae['method'].isin(['KM2', 'DRE'])]
df_mae["method"] = df_mae["method"].replace({"MLLS_NNPU": "MLLS (nnPU)", "MLLS_DRPU": "MLLS (DRPU)", "DRE_FROM_MIXED": "DRE (Target)"})
plot_mae(df_mae, train_pis[0], test_pis, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='fashionmnist', identifier=None, is_real=True)
# Out:
# Saved plot to results_img\fashionmnist_0.5_mae.png

# %%
# Average Balanced Accuracy of different trained classifiers for FashionMNIST Dataset (n = n′ = 5000, K = 10)

dataset_name = 'FashionMNIST'
mean = None
n = 5000
label_frequency = 0.5
train_pis = [0.5]
test_pis = [0.2, 0.4, 0.6, 0.8]

df_metric = evaluate_all_metrics(dataset_name, mean, n, label_frequency, train_pis, test_pis, convert_to_df=True, single_exp=False)
df_metric = df_metric[df_metric['metric'].isin(['balanced_accuracy'])]
df_metric = df_metric[df_metric['method'].isin(['DRPU', 'nnPU', 'nnPU+TA+KM2', 'DRPU+TA+KM2', 'nnPU+Target'])]

plot_metric(df_metric, 'Balanced Accuracy', train_pis[0], test_pis, label_frequency, verbose=True, show_se=True, K=10, save=True, dataset_name='fashionmnist', identifier='', is_real=True)
# Out:
# Saved plot to results_img\fashionmnist_0.5_balanced_accuracy.png

# %%
# ROC Curve

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.5, 0.2), (0.5, 0.4), (0.5, 0.6), (0.5, 0.8)]
metrics_list = []
for train_pi, test_pi in pi_pairs:
    file_path = f"output/FashionMNIST/{n}/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics_list.append(json.load(f))

plot_roc_grid(
    metrics_list,  
    model='nnpu',
    pi_pairs=pi_pairs,
    save=True,
    dataset_name='fashionmnist'
)
# Out:
# Saved plot to results_img\fashionmnist_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_roc_grid_nnpu.png
# (<Figure size 1000x1000 with 4 Axes>,
#  array([<Axes: title={'center': "$\\pi=0.5, \\pi'=0.2$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.4$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.6$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.8$"}, xlabel='FPR', ylabel='TPR'>],
#        dtype=object))

# %%
# ROC Curve

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.5, 0.2), (0.5, 0.4), (0.5, 0.6), (0.5, 0.8)]
metrics_list = []
for train_pi, test_pi in pi_pairs:
    file_path = f"output/FashionMNIST/{n}/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics_list.append(json.load(f))

plot_roc_grid(
    metrics_list,  
    model='drpu',
    pi_pairs=pi_pairs,
    save=True,
    dataset_name='fashionmnist'
)
# Out:
# Saved plot to results_img\fashionmnist_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_roc_grid_drpu.png
# (<Figure size 1000x1000 with 4 Axes>,
#  array([<Axes: title={'center': "$\\pi=0.5, \\pi'=0.2$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.4$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.6$"}, xlabel='FPR', ylabel='TPR'>,
#         <Axes: title={'center': "$\\pi=0.5, \\pi'=0.8$"}, xlabel='FPR', ylabel='TPR'>],
#        dtype=object))

# %%
# Accuracy as function of threshold

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.5, 0.2), (0.5, 0.4), (0.5, 0.6), (0.5, 0.8)]
metrics_list = []
threshold_list = []

for train_pi, test_pi in pi_pairs:
    file_path = f"output/FashionMNIST/{n}/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
    with open(file_path, "r") as f:
        metrics = json.load(f)
        metrics_list.append(metrics["accuracy-ta-grid"])

        threshold_list.append((
            metrics["nnPU+TA+KM2"]["threshold"],
            metrics["nnPU+TA+DRE"]["threshold"],
            metrics["nnPU+TA+True"]["threshold"]
        ))

plot_accuracy_threshold(
    metrics_list,
    pi_pairs=pi_pairs,
    thresholds_list=threshold_list,
    save=True,
    dataset_name='fashionmnist',
)
# Out:
# Saved plot to results_img\fashionmnist_accuracy_threshold_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_.png
# (<Figure size 1200x1600 with 8 Axes>,
#  array([[<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>],
#         [<Axes: title={'center': 'nnPU'}, xlabel='Threshold', ylabel='Accuracy'>,
#          <Axes: title={'center': 'DRPU'}, xlabel='Threshold', ylabel='Accuracy'>]],
#        dtype=object))

# %% [markdown]
# ## Real Datasets
#
# * MNIST,
# * FashionMNIST,
# * ChestXRay,
# * Electricity,
# * Covertype,
# * SMSSpam

# %%
# Average Accuracy of different trained classifiers for real datasets (n = n′ = 5000, K = 10)
# Average Balanced Accuracy of different trained classifiers for real datasets (n = n′ = 5000, K = 10)
# Mean Absolute Error of test prior estimation for real datasets (n = n′ = 5000, K = 10)

plot_real_accuracy_grid(save=True, save_plot_name='real')
plot_real_accuracy_grid(metric='balanced_accuracy', save=True, save_plot_name='real')
plot_real_mae_grid(save=True, save_plot_name='real')
# Out:
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Saved plot to results_img\real_0.5_accuracy.png
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Warning: Method nnPU+KM2 not found in metrics for exp 0
# Warning: Method nnPU+KM2 not found in metrics for exp 1
# Warning: Method nnPU+KM2 not found in metrics for exp 2
# Warning: Method nnPU+KM2 not found in metrics for exp 3
# Warning: Method nnPU+KM2 not found in metrics for exp 4
# Warning: Method nnPU+KM2 not found in metrics for exp 5
# Warning: Method nnPU+KM2 not found in metrics for exp 6
# Warning: Method nnPU+KM2 not found in metrics for exp 7
# Warning: Method nnPU+KM2 not found in metrics for exp 8
# Warning: Method nnPU+KM2 not found in metrics for exp 9
# Saved plot to results_img\real_0.5_balanced_accuracy.png
# Saved plot to results_img\real_0.5_mae.png
# (<Figure size 1100x1300 with 6 Axes>,
#  array([[<Axes: title={'center': 'MNIST'}, xlabel='Target class prior', ylabel='MAE'>,
#          <Axes: title={'center': 'FashionMNIST'}, xlabel='Target class prior'>],
#         [<Axes: title={'center': 'ChestXRay'}, xlabel='Target class prior', ylabel='MAE'>,
#          <Axes: title={'center': 'Electricity'}, xlabel='Target class prior'>],
#         [<Axes: title={'center': 'Covertype'}, xlabel='Target class prior', ylabel='MAE'>,
#          <Axes: title={'center': 'SMSSpam'}, xlabel='Target class prior'>]],
#        dtype=object))

# %%
# Accuracy as function of threshold

n = 5000
label_frequency = 0.5
exp_number = 0
pi_pairs = [(0.5, 0.2), (0.5, 0.4), (0.5, 0.6), (0.5, 0.8)]

dataset_names = [
    "MNIST",
    "FashionMNIST",
    "ChestXRay",
    "Electricity",
    "Covertype",
    "SMSSpam",
]

for dataset_name in dataset_names:
    metrics_list = []
    threshold_list = []
    for train_pi, test_pi in pi_pairs:
        file_path = f"output/{dataset_name}/{n}/{train_pi}/{test_pi}/{label_frequency}/{exp_number}/metrics.json"
        with open(file_path, "r") as f:
            metrics = json.load(f)
            metrics_list.append(metrics["accuracy-ta-grid"])

        threshold_list.append((
            metrics["nnPU+TA+KM2"]["threshold"],
            metrics["nnPU+TA+DRE"]["threshold"],
            metrics["nnPU+TA+True"]["threshold"]
        ))

    plot_accuracy_threshold(
        metrics_list,
        pi_pairs=pi_pairs,
        thresholds_list=threshold_list,
        save=True,
        dataset_name=dataset_name.lower(),
    )
# Out:
# Saved plot to results_img\mnist_accuracy_threshold_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_.png
# Saved plot to results_img\fashionmnist_accuracy_threshold_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_.png
# Saved plot to results_img\chestxray_accuracy_threshold_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_.png
# Saved plot to results_img\electricity_accuracy_threshold_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_.png
# Saved plot to results_img\covertype_accuracy_threshold_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_.png
# Saved plot to results_img\smsspam_accuracy_threshold_0.5-0.2_0.5-0.4_0.5-0.6_0.5-0.8_.png

# %% [markdown]
# ### all data

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# for method in df["method"].unique():
#     df_method = df[df["method"] == method]
#     plt.figure(figsize=(6, 4))
#     plt.title(f"Estimated pi ({method})")
#     sns.heatmap(df_method.pivot(index="pi", columns="new_pi", values="mean"), annot=True, fmt=".2f", 
#         cmap= "PiYG",
#         vmin= min(df_method["mean"]),
#         vmax= max(df_method["mean"]),
#         center=0)
#     plt.show()
