# %%
from src.nnPU.src.nnPUss.dataset_configs import DatasetConfig
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.nnPU.src.nnPUss.dataset_configs import DatasetConfig
#
# File c:\Users\izate\github\2026-PULS-Master\src\nnPU\src\nnPUss\dataset_configs.py:1
# ----> 1 from nnPU.dataset import (
#       2     CIFAR_PU,
#       3     IMDB_PU,
#       4     MNIST_PU,
#       5     Beans_PU,
#       6     ChestXRay_PU,
#       7     DogFood_PU,
#       8     EuroSAT_PU,
#       9     FashionMNIST_PU,
#      10     HateSpeech_PU,
#      11     OxfordPets_PU,
#      12     PoemSentiment_PU,
#      13     PUDatasetBase,
#      14     PULabeler,
#      15     SCAR_CC_Labeler,
#      16     SCAR_SS_Labeler,
#      17     SMSSpam_PU,
#      18     Snacks_PU,
#      19     TBCalifornia_PU,
#      20     TBCredit_PU,
#      21     TBElectricity_PU,
#      22     TBWine_PU,
#      23     TwentyNews_PU,
#      24 )
# ...

# %%
DatasetConfig
# Out:
# src.nnPU.src.nnPUss.dataset_configs.DatasetConfig
